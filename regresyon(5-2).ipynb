# %%
import matplotlib.pyplot as plt
from scipy.stats.stats import ttest_ind
import pandas as pd
from sklearn import linear_model
import numpy as np
import seaborn as sns
from pylab import rcParams
import plotly.express as px
import warnings
from scipy.stats.mstats import winsorize

warnings.filterwarnings('ignore')

# %%
ev_fiyatları = pd.read_csv("ev_fiyatları.csv")
ev_fiyatları.head()
# Out:
#    Unnamed: 0  Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 0           0   1          60       RL         65.0     8450   Pave  None
# 1           1   2          20       RL         80.0     9600   Pave  None
# 2           2   3          60       RL         68.0    11250   Pave  None
# 3           3   4          70       RL         60.0     9550   Pave  None
# 4           4   5          60       RL         84.0    14260   Pave  None
#
#   LotShape LandContour  ... MoSold YrSold SaleType SaleCondition SalePrice  \
# 0      Reg         Lvl  ...      2   2008       WD        Normal    208500
# 1      Reg         Lvl  ...      5   2007       WD        Normal    181500
# 2      IR1         Lvl  ...      9   2008       WD        Normal    223500
# 3      IR1         Lvl  ...      2   2006       WD       Abnorml    140000
# 4      IR1         Lvl  ...     12   2008       WD        Normal    250000
#
#   PoolQC_ CentralAir_ Alley_  Fence_  LandContour_
# ...

# %%
ev_fiyatları.head(8)
# Out:
#    Unnamed: 0  Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 0           0   1          60       RL         65.0     8450   Pave  None
# 1           1   2          20       RL         80.0     9600   Pave  None
# 2           2   3          60       RL         68.0    11250   Pave  None
# 3           3   4          70       RL         60.0     9550   Pave  None
# 4           4   5          60       RL         84.0    14260   Pave  None
# 5           5   6          50       RL         85.0    14115   Pave  None
# 6           6   7          20       RL         75.0    10084   Pave  None
# 7           7   8          60       RL          NaN    10382   Pave  None
#
#   LotShape LandContour  ... MoSold YrSold SaleType SaleCondition SalePrice  \
# 0      Reg         Lvl  ...      2   2008       WD        Normal    208500
# 1      Reg         Lvl  ...      5   2007       WD        Normal    181500
# 2      IR1         Lvl  ...      9   2008       WD        Normal    223500
# ...

# %%
Y = ev_fiyatları['SalePrice']
X = ev_fiyatları[["OverallCond","Alley_","CentralAir_","PoolQC_","LandContour_","OverallQual"]]

# %%
lrm = linear_model.LinearRegression()
lrm.fit(X, Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print('Değişkenler: \n', lrm.coef_)
print('Sabit değer (bias): \n', lrm.intercept_)
# Out:
# Değişkenler:
#  [  -513.49074321 -14212.29705928  10563.47122806  27912.17740264
#    7861.00626415  44397.53680285]
# Sabit değer (bias):
#  -97427.75405178385

# %%
import statsmodels.api as sm

X = sm.add_constant(X)
results = sm.OLS(Y, X).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.638
# Model:                            OLS   Adj. R-squared:                  0.637
# Method:                 Least Squares   F-statistic:                     427.1
# Date:                Thu, 30 Apr 2020   Prob (F-statistic):          2.35e-316
# Time:                        19:46:37   Log-Likelihood:                -17790.
# No. Observations:                1459   AIC:                         3.559e+04
# Df Residuals:                    1452   BIC:                         3.563e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
results.params
# Out:
# const          -97427.754052
# OverallCond      -513.490743
# Alley_         -14212.297059
# CentralAir_     10563.471228
# PoolQC_         27912.177403
# LandContour_     7861.006264
# OverallQual     44397.536803
# dtype: float64

# %%
del X["OverallCond"]

# %%
X = sm.add_constant(X)
results = sm.OLS(Y, X).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.638
# Model:                            OLS   Adj. R-squared:                  0.637
# Method:                 Least Squares   F-statistic:                     512.8
# Date:                Thu, 30 Apr 2020   Prob (F-statistic):          1.09e-317
# Time:                        19:46:37   Log-Likelihood:                -17790.
# No. Observations:                1459   AIC:                         3.559e+04
# Df Residuals:                    1453   BIC:                         3.562e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
ev_fiyatları.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 87 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     1459 non-null   int64
#  1   Id             1459 non-null   int64
#  2   MSSubClass     1459 non-null   int64
#  3   MSZoning       1459 non-null   object
#  4   LotFrontage    1200 non-null   float64
#  5   LotArea        1459 non-null   int64
#  6   Street         1459 non-null   object
#  7   Alley          1459 non-null   object
#  8   LotShape       1459 non-null   object
#  9   LandContour    1459 non-null   object
#  10  Utilities      1459 non-null   object
#  11  LotConfig      1459 non-null   object
#  12  LandSlope      1459 non-null   object
#  13  Neighborhood   1459 non-null   object
#  14  Condition1     1459 non-null   object
#  15  Condition2     1459 non-null   object
#  16  BldgType       1459 non-null   object
# ...

# %%
X = ev_fiyatları[["PoolArea","YearBuilt","LotArea","ExterQual","Alley_","CentralAir_","PoolQC_","LandContour_","OverallQual" , "TotRmsAbvGrd"]]

# %%
X = sm.add_constant(X)
results = sm.OLS(Y, X).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.734
# Model:                            OLS   Adj. R-squared:                  0.732
# Method:                 Least Squares   F-statistic:                     399.8
# Date:                Thu, 30 Apr 2020   Prob (F-statistic):               0.00
# Time:                        19:46:38   Log-Likelihood:                -17565.
# No. Observations:                1459   AIC:                         3.515e+04
# Df Residuals:                    1448   BIC:                         3.521e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
X["OverallQual**"]= X["OverallQual"]**2

# %%
X
# Out:
#       const  PoolArea  YearBuilt  LotArea  ExterQual  Alley_  CentralAir_  \
# 0       1.0         0       2003     8450          3       0            1
# 1       1.0         0       1976     9600          2       0            1
# 2       1.0         0       2001    11250          3       0            1
# 3       1.0         0       1915     9550          2       0            1
# 4       1.0         0       2000    14260          3       0            1
# ...     ...       ...        ...      ...        ...     ...          ...
# 1454    1.0         0       1999     7917          2       0            1
# 1455    1.0         0       1978    13175          2       0            1
# 1456    1.0         0       1941     9042          4       0            1
# 1457    1.0         0       1950     9717          2       0            1
# 1458    1.0         0       1965     9937          3       0            1
#
#       PoolQC_  LandContour_  OverallQual  TotRmsAbvGrd  OverallQual**
# ...

# %%
X = sm.add_constant(X)
results = sm.OLS(Y, X).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.768
# Model:                            OLS   Adj. R-squared:                  0.766
# Method:                 Least Squares   F-statistic:                     435.4
# Date:                Thu, 30 Apr 2020   Prob (F-statistic):               0.00
# Time:                        19:46:38   Log-Likelihood:                -17466.
# No. Observations:                1459   AIC:                         3.496e+04
# Df Residuals:                    1447   BIC:                         3.502e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
X["OverallQual* TotRmsAbvGrd"]= X["OverallQual"]* X["TotRmsAbvGrd"]
del X["TotRmsAbvGrd"]

# %%
X = sm.add_constant(X)
results = sm.OLS(Y, X).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.772
# Model:                            OLS   Adj. R-squared:                  0.771
# Method:                 Least Squares   F-statistic:                     446.7
# Date:                Thu, 30 Apr 2020   Prob (F-statistic):               0.00
# Time:                        19:46:39   Log-Likelihood:                -17452.
# No. Observations:                1459   AIC:                         3.493e+04
# Df Residuals:                    1447   BIC:                         3.499e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# ...

# %%
del X["PoolArea"]
del X["PoolQC_"]

# %%
X = sm.add_constant(X)
results = sm.OLS(Y, X).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.772
# Model:                            OLS   Adj. R-squared:                  0.771
# Method:                 Least Squares   F-statistic:                     545.9
# Date:                Thu, 30 Apr 2020   Prob (F-statistic):               0.00
# Time:                        19:46:39   Log-Likelihood:                -17453.
# No. Observations:                1459   AIC:                         3.493e+04
# Df Residuals:                    1449   BIC:                         3.498e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# ...
